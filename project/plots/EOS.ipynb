# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/hugens/shared/uni/modsim/modsim/project/plots

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/backup/EOS/'
os.chdir(dirr)
betaPv0s = [];
avg_rhos = [];
avg_Ss   = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    betaPv0 = int(line.split("\n")[0])
    betaPv0s.append(betaPv0)
    steps, rhos, Ss = np.loadtxt(file, skiprows=1).transpose()
    avg_rhos.append(np.mean(rhos))
    avg_Ss.append(np.mean(Ss))
    plt.plot(steps, rhos, label="b = " + str(betaPv0))
    plt.xlabel('steps')
    plt.ylabel('rho')
#     plt.show()
    plt.legend()
plt.show()
plt.plot(avg_rhos, betaPv0s, '.')
plt.show()
plt.plot(avg_rhos, avg_Ss, '.')

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/EOS/'
os.chdir(dirr)
betaPv0s = [];
avg_rhos = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    betaPv0 = int(line.split("\n")[0])
    betaPv0s.append(betaPv0)
    steps, rhos = np.loadtxt(file, skiprows=1).transpose()
    avg_rhos.append(np.mean(rhos))
    plt.plot(steps, rhos, label="b = " + str(betaPv0))
    plt.xlabel('steps')
    plt.ylabel('rho')
#     plt.show()
    plt.legend()
plt.show()
plt.plot(betaPv0s, avg_rhos)

# %%
betaP = 0.694494
N = 666
V = np.linspace(100, 4000, 100)
v = jjjjjjjjjjjjjjjjjj
delta_V = np.linspace(-30, 30, 1000)
# for v in V:
plt.plot(delta_V, np.exp(-betaP*delta_V + N*np.log(1 + delta_V/v)))

# %%
betaPv0 = 2
L = 3
v0 = np.pi * (L / 4 + 1 / 6);
print(betaPv0/v0)
# Out:
# 0.6944942971282706

# %%
file = '/home/hugens/shared/uni/modsim/modsim/project/parameters.txt'
data = np.loadtxt(file, skiprows=1)

# %%
data = data[data[:, 2].argsort()]

# %%
data
# Out:
# array([[1.00000e-03, 1.00000e-03, 1.00000e+00, 1.00000e-01, 2.80561e-01],
#        [1.00000e-03, 1.00000e-02, 1.00000e+00, 3.00000e-01, 3.49699e-01],
#        [1.00000e-02, 1.00000e-03, 1.00000e+00, 3.00000e-01, 3.61000e-01],
#        [1.00000e-01, 1.00000e-03, 1.00000e+00, 3.00000e-01, 3.39376e-01],
#        [1.00000e-03, 1.00000e-03, 1.00000e+00, 3.00000e-01, 3.40361e-01],
#        [1.00000e-01, 1.00000e-02, 1.00000e+00, 3.00000e-01, 3.18870e-01],
#        [1.00000e-01, 1.00000e-01, 1.00000e+00, 3.00000e-01, 3.73869e-01],
#        [1.00000e-02, 1.00000e-01, 1.00000e+00, 3.00000e-01, 3.40000e-01],
#        [1.00000e-02, 1.00000e-02, 1.00000e+00, 3.00000e-01, 3.68104e-01],
#        [1.00000e-01, 1.00000e-01, 1.00000e+00, 5.00000e-01, 4.73000e-01],
#        [1.00000e-01, 1.00000e-01, 1.00000e+00, 1.00000e-01, 2.80000e-01],
#        [1.00000e-03, 1.00000e-02, 1.00000e+00, 1.00000e-01, 2.79000e-01],
#        [1.00000e-03, 1.00000e-03, 1.00000e+00, 5.00000e-01, 4.15832e-01],
# ...
