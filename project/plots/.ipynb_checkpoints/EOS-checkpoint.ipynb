# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pwdj
# Out:
# /home/hugens/shared/uni/modsim/modsim/project/plots

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/backup/EOS/'
os.chdir(dirr)
betaPv0s = [];
avg_rhos = [];
avg_Ss   = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    betaPv0 = int(line.split("\n")[0])
    betaPv0s.append(betaPv0)
    steps, rhos, Ss = np.loadtxt(file, skiprows=1).transpose()
    avg_rhos.append(np.mean(rhos))
    avg_Ss.append(np.mean(Ss))
    plt.plot(steps, rhos, label="b = " + str(betaPv0))
    plt.xlabel('steps')
    plt.ylabel('rho')
#     plt.show()
    plt.legend()
plt.show()
plt.plot(avg_rhos, betaPv0s, '.')
plt.show()
plt.plot(avg_rhos, avg_Ss, '.')

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/EOS/'
os.chdir(dirr)
betaPv0s = [];
avg_rhos = [];
avg_Ss   = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    betaPv0 = int(line.split("\n")[0])
    betaPv0s.append(betaPv0)
    steps, rhos, Ss = np.loadtxt(file, skiprows=1).transpose()
    avg_rhos.append(np.mean(rhos))
    avg_Ss.append(np.mean(Ss))
    plt.plot(steps, rhos, label="b = " + str(betaPv0))
    plt.xlabel('steps')
    plt.ylabel('rho')
#     plt.show()
    plt.legend()
plt.show()
plt.plot(avg_rhos, betaPv0s, '.')
plt.show()
plt.plot(avg_rhos, avg_Ss, '.')

# %%
file = '/home/hugens/shared/uni/modsim/modsim/project/parameters.txt'
data = np.loadtxt(file, skiprows=1)

# %%
data = data[data[:, 2].argsort()]

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/SL/'
os.chdir(dirr)
Ls = [];
avg_Ss = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    L = float(line.split("\n")[0])
    Ls.append(L)
    steps, Ss = np.loadtxt(file, skiprows=1).transpose()
    avg_Ss.append(np.mean(Ss))
    plt.plot(steps, Ss, label="L = " + str(L))
    plt.xlabel('steps')
    plt.ylabel('S')
#     plt.show()
    plt.legend()
plt.show()
plt.plot(Ls, avg_Ss, '.')

# %%
dirr = '/home/hugens/shared/uni/modsim/modsim/project/NPT/'
os.chdir(dirr)
betaPv0s = [];
avg_rhos = [];
avg_Ss   = [];
for file in os.listdir(os.getcwd()):
    f = open(file)
    line = f.readline()
    betaPv0 = int(line.split("\n")[0])
    betaPv0s.append(betaPv0)
    steps, rhos, Ss = np.loadtxt(file, skiprows=1).transpose()
    avg_rhos.append(np.mean(rhos))
    avg_Ss.append(np.mean(Ss))
    plt.plot(steps, rhos, label="b = " + str(betaPv0))
    plt.show()
    plt.plot(steps, Ss, label="b = " + str(betaPv0))
    plt.xlabel('steps')
    plt.ylabel('rho')
#     plt.show()
    plt.legend()
